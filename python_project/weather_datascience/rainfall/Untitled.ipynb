# %%
import pandas as pd
import os
import numpy as np

# %%
dir(os)
help(os.mkdir)
# Out:
# Help on built-in function mkdir in module posix:
#
# mkdir(path, mode=511, *, dir_fd=None)
#     Create a directory.
#
#     If dir_fd is not None, it should be a file descriptor open to a directory,
#       and path should be relative; path will then be relative to that directory.
#     dir_fd may not be implemented on your platform.
#       If it is unavailable, using it will raise a NotImplementedError.
#
#     The mode argument is ignored on Windows.

# %%
file = pd.read_csv('datafile.csv')

# %%
file
# Out:
#      YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG    SEP    OCT  \
# 0    1901  34.7  38.6  17.8  38.9  50.6  113.2  241.4  271.6  124.7   52.4
# 1    1902   7.4   4.2  19.0  44.1  48.8  111.7  284.9  201.0  200.2   62.5
# 2    1903  16.7   8.0  31.1  17.1  59.5  120.3  293.2  274.0  198.1  119.5
# 3    1904  14.9   9.7  31.4  33.7  73.8  165.5  260.3  207.7  130.8   69.8
# 4    1905  24.7  20.3  41.8  33.8  55.8   93.7  253.0  201.7  178.1   54.9
# ..    ...   ...   ...   ...   ...   ...    ...    ...    ...    ...    ...
# 108  2009  12.0  12.0  14.2  25.1  56.0   85.7  280.7  192.5  139.4   71.4
# 109  2010   7.5  17.0  14.0  39.0  73.8  138.1  300.7  274.7  197.7   69.0
# 110  2011   6.8  25.8  22.4  41.1  53.1  183.5  246.0  284.9  186.9   38.1
# 111  2012  26.5  12.7  11.3  47.5  31.7  117.8  250.2  262.4  193.5   58.7
# 112  2013  11.3  40.1  15.7  30.4  57.8  219.8  310.0  254.7  152.7  129.4
#
#       NOV   DEC     ANN  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
file = pd.read_csv('datafile.csv',index_col=0)
file
# Out:
#        JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG    SEP    OCT   NOV  \
# YEAR
# 1901  34.7  38.6  17.8  38.9  50.6  113.2  241.4  271.6  124.7   52.4  38.7
# 1902   7.4   4.2  19.0  44.1  48.8  111.7  284.9  201.0  200.2   62.5  29.4
# 1903  16.7   8.0  31.1  17.1  59.5  120.3  293.2  274.0  198.1  119.5  40.3
# 1904  14.9   9.7  31.4  33.7  73.8  165.5  260.3  207.7  130.8   69.8  11.2
# 1905  24.7  20.3  41.8  33.8  55.8   93.7  253.0  201.7  178.1   54.9   9.6
# ...    ...   ...   ...   ...   ...    ...    ...    ...    ...    ...   ...
# 2009  12.0  12.0  14.2  25.1  56.0   85.7  280.7  192.5  139.4   71.4  53.7
# 2010   7.5  17.0  14.0  39.0  73.8  138.1  300.7  274.7  197.7   69.0  61.4
# 2011   6.8  25.8  22.4  41.1  53.1  183.5  246.0  284.9  186.9   38.1  20.1
# 2012  26.5  12.7  11.3  47.5  31.7  117.8  250.2  262.4  193.5   58.7  30.7
# 2013  11.3  40.1  15.7  30.4  57.8  219.8  310.0  254.7  152.7  129.4  14.0
#
# ...

# %%
#creating copy of original data
#Shallow and deep copy

#DataFrame.index(row labels)

file.index
# Out:
# Int64Index([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910,
#             ...
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013],
#            dtype='int64', name='YEAR', length=113)

# %%
 
file.columns
# Out:
# Index(['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
#        'NOV', 'DEC', 'ANN', 'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
file.size
# Out:
# 1921

# %%
file.shape
# Out:
# (113, 17)

# %%
file.memory_usage()
# Out:
# Index      904
# JAN        904
# FEB        904
# MAR        904
# APR        904
# MAY        904
# JUN        904
# JUL        904
# AUG        904
# SEP        904
# OCT        904
# NOV        904
# DEC        904
# ANN        904
# Jan-Feb    904
# Mar-May    904
# Jun-Sep    904
# Oct-Dec    904
# dtype: int64

# %%
file.ndim
# Out:
# 2

# %%
file.head()
# Out:
#        JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG    SEP    OCT   NOV  \
# YEAR
# 1901  34.7  38.6  17.8  38.9  50.6  113.2  241.4  271.6  124.7   52.4  38.7
# 1902   7.4   4.2  19.0  44.1  48.8  111.7  284.9  201.0  200.2   62.5  29.4
# 1903  16.7   8.0  31.1  17.1  59.5  120.3  293.2  274.0  198.1  119.5  40.3
# 1904  14.9   9.7  31.4  33.7  73.8  165.5  260.3  207.7  130.8   69.8  11.2
# 1905  24.7  20.3  41.8  33.8  55.8   93.7  253.0  201.7  178.1   54.9   9.6
#
#        DEC     ANN  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# YEAR
# 1901   8.2  1030.8     73.2    107.3    751.0     99.3
# 1902  25.2  1038.4     11.6    111.9    797.8    117.2
# 1903  18.0  1195.9     24.7    107.7    885.6    177.8
# 1904  16.4  1025.1     24.5    138.8    764.3     97.4
# 1905  10.1   977.5     45.0    131.4    726.4     74.7

# %%
a = file.loc[1901,'JAN']
print(a)
# Out:
# 34.7

# %%
test = file.loc[:,['JAN','FEB']]

# %%
print(test)
# Out:
#        JAN   FEB
# YEAR
# 1901  34.7  38.6
# 1902   7.4   4.2
# 1903  16.7   8.0
# 1904  14.9   9.7
# 1905  24.7  20.3
# ...    ...   ...
# 2009  12.0  12.0
# 2010   7.5  17.0
# 2011   6.8  25.8
# 2012  26.5  12.7
# 2013  11.3  40.1
#
# [113 rows x 2 columns]

# %%
test1 = file.iloc[0]
test1
# Out:
# JAN          34.7
# FEB          38.6
# MAR          17.8
# APR          38.9
# MAY          50.6
# JUN         113.2
# JUL         241.4
# AUG         271.6
# SEP         124.7
# OCT          52.4
# NOV          38.7
# DEC           8.2
# ANN        1030.8
# Jan-Feb      73.2
# Mar-May     107.3
# Jun-Sep     751.0
# Oct-Dec      99.3
# Name: 1901, dtype: float64

# %%
file.loc[:,'ANN']
# Out:
# YEAR
# 1901    1030.8
# 1902    1038.4
# 1903    1195.9
# 1904    1025.1
# 1905     977.5
#          ...
# 2009     953.7
# 2010    1215.5
# 2011    1116.3
# 2012    1054.7
# 2013    1092.5
# Name: ANN, Length: 113, dtype: float64

# %%
#Histogram:

"""The histogram represents the frequency of occurrence of 
specific phenomena which lie within a specific range of values and
arranged in consecutive and fixed intervals."""
import pandas as pd 

import matplotlib.pyplot as plt
df = pd.read_csv('datafile.csv')

df.hist()
plt.show()

# %%
df.plot.bar()

# %%
# plot between 2 attributes 
plt.bar(df['YEAR'], df['ANN']) 
plt.xlabel("YEAR") 
plt.ylabel("ANN") 
plt.show()
