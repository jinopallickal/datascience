# %%
import pandas as pd
from matplotlib import pyplot as plt

f = pd.read_csv("climate_change_upto_2000_1.csv",sep=",")

# %%
f.head()
# Out:
#   Station Name     Month     Period  No. of Years  \
# 0          Abu   January  1901-2000           100
# 1          Abu  February  1901-2000           100
# 2          Abu     March  1901-2000           100
# 3          Abu     April  1901-2000           100
# 4          Abu       May  1901-2000           100
#
#    Mean Temperature in degree C - Maximum  \
# 0                                    19.3
# 1                                    21.0
# 2                                    25.3
# 3                                    29.4
# 4                                    31.5
#
#    Mean Temperature  in degree C - Minimum  Mean Rainfall in mm
# 0                                      8.0                  5.3
# 1                                     10.0                  4.4
# 2                                     14.5                  6.5
# 3                                     18.7                  2.6
# 4                                     21.0                 16.4

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332 entries, 0 to 1331
# Data columns (total 7 columns):
# Station Name                               1332 non-null object
# Month                                      1332 non-null object
# Period                                     1332 non-null object
# No. of Years                               1332 non-null int64
# Mean Temperature in degree C - Maximum     1332 non-null float64
# Mean Temperature  in degree C - Minimum    1332 non-null float64
# Mean Rainfall in mm                        1332 non-null float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 73.0+ KB

# %%
f.describe()

plt.plot(f.Month, f.Period)
plt.show()

# %%
f.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff986d8a908>,
# ...
#       dtype=object)

# %%
f['Mean Rainfall in mm'].plot(kind='hist');

# %%
plt.plot(f['Mean Temperature in degree C - Minimum'], f['Mean Rainfall in mm'], 'ro--')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mean Temperature in degree C - Minimum'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-58cbc71ee326> in <module>
# ...

# %%
print(f[:,5:7])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-989143dffdba> in <module>
# ----> 1 print(f[:,5:7])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
# ...
