# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = pd.read_csv("Sub_Division_IMD_2017.csv")
file = file.fillna(file.mean())

# %%
file.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  Andaman & Nicobar Islands  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  Andaman & Nicobar Islands  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  Andaman & Nicobar Islands  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  Andaman & Nicobar Islands  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  Andaman & Nicobar Islands  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM    JJAS  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2  136.3  560.3  1696.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7  159.8  458.3  2185.9
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4  156.7  236.1  1874.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6   24.1  506.9  1977.6
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7    1.3  309.7  1624.9
#
#      OND
# 0  980.3
# 1  716.7
# 2  690.6
# 3  571.0
# 4  630.8

# %%
plt.figure(figsize=(11,4))
sns.heatmap(file[['JF','MAM','JJAS','OND','ANNUAL']].corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(11,4))
sns.heatmap(file[['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','ANNUAL']].corr(),annot=True)
plt.show()

# %%
# seperation of training and testing data
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
division_data = np.asarray(file[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']])

# %%
X = None; y = None
for i in range(division_data.shape[1]-3):
    if X is None:
        X = division_data[:, i:i+3]
        y = division_data[:, i+3]
    else:
        X = np.concatenate((X, division_data[:, i:i+3]), axis=0)
        y = np.concatenate((y, division_data[:, i+3]), axis=0)
        
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
#test 2015
temp = file[['SUBDIVISION','JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].loc[file['YEAR'] == 2015]

data_2015 = np.asarray(temp[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].loc[temp['SUBDIVISION'] == 'KERALA'])

X_year_2015 = None; y_year_2015= None
for i in range(data_2015.shape[1]-3):
    if X_year_2015 is None:
        X_year_2015 = data_2015[:, i:i+3]
        y_year_2015 = data_2015[:, i+3]
    else:
        X_year_2015 = np.concatenate((X_year_2015, data_2015[:, i:i+3]), axis=0)
        y_year_2015 = np.concatenate((y_year_2015, data_2015[:, i+3]), axis=0)

# %%
#test 2016
temp = file[['SUBDIVISION','JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].loc[file['YEAR'] == 2016]

data_2016 = np.asarray(temp[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].loc[temp['SUBDIVISION'] == 'KERALA'])

X_year_2016 = None; y_year_2016= None
for i in range(data_2016.shape[1]-3):
    if X_year_2016 is None:
        X_year_2016 = data_2016[:, i:i+3]
        y_year_2016 = data_2016[:, i+3]
    else:
        X_year_2016 = np.concatenate((X_year_2016, data_2016[:, i:i+3]), axis=0)
        y_year_2016 = np.concatenate((y_year_2016, data_2016[:, i+3]), axis=0)

# %%
#test 2017
temp = file[['SUBDIVISION','JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].loc[file['YEAR'] == 2017]

data_2017 = np.asarray(temp[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].loc[temp['SUBDIVISION'] == 'KERALA'])

X_year_2017 = None; y_year_2017= None
for i in range(data_2017.shape[1]-3):
    if X_year_2017 is None:
        X_year_2017 = data_2017[:, i:i+3]
        y_year_2017 = data_2017[:, i+3]
    else:
        X_year_2017 = np.concatenate((X_year_2017, data_2017[:, i:i+3]), axis=0)
        y_year_2017 = np.concatenate((y_year_2017, data_2017[:, i+3]), axis=0)

# %%
from sklearn import linear_model

# linear model
reg = linear_model.ElasticNet(alpha=0.5)

# %% [raw]
# reg.fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)
print mean_absolute_error(y_test, y_pred)
# Out:
#   File "<ipython-input-102-36735d7f160b>", line 2
#     print mean_absolute_error(y_test, y_pred)
#                             ^
# SyntaxError: invalid syntax

# %%
#2015
import numpy as np
y_year_pred_2015 = reg.predict(X_year_2015)


#2016
y_year_pred_2016 = reg.predict(X_year_2016)
    
y_year_pred_2017 = reg.predict(X_year_2017)

print ("MEAN 2015")
print (np.mean(y_year_2015),np.mean(y_year_pred_2015))
print ("Standard deviation 2015")
print (np.sqrt(np.var(y_year_2015)),np.sqrt(np.var(y_year_pred_2015)))


print ("MEAN 2016")
print (np.mean(y_year_2016),np.mean(y_year_pred_2016))
print ("Standard deviation 2016")
print (np.sqrt(np.var(y_year_2016)),np.sqrt(np.var(y_year_pred_2016)))


print ("MEAN 2017")
print (np.mean(y_year_2017),np.mean(y_year_pred_2017))
print ("Standard deviation 2017")
print (np.sqrt(np.var(y_year_2017)),np.sqrt(np.var(y_year_pred_2017)))


plot_graphs(y_year_2015,y_year_pred_2015,"Year-2015")
plot_graphs(y_year_2016,y_year_pred_2016,"Year-2016")
plot_graphs(y_year_2017,y_year_pred_2017,"Year-2017")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-67-54912e8bf9a9> in <module>
#       1 #2015
#       2 import numpy as np
# ----> 3 y_year_pred_2015 = reg.predict(X_year_2015)
#       4
#       5
#
# ~/.local/lib/python3.6/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/.local/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py in _decision_function(self, X)
#     787             The predicted decision function
#     788         """
# --> 789         check_is_fitted(self)
#     790         if sparse.isspmatrix(X):
#     791             return safe_sparse_dot(X, self.coef_.T,
#
# ...
