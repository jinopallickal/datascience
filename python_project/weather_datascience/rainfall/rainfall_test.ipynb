# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
file = pd.read_csv("Sub_Division_IMD_2017.csv")

# %%
file
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     Andaman & Nicobar Islands  1901  49.2   87.1   29.2    2.3  528.8
# 1     Andaman & Nicobar Islands  1902   0.0  159.8   12.2    0.0  446.1
# 2     Andaman & Nicobar Islands  1903  12.7  144.0    0.0    1.0  235.1
# 3     Andaman & Nicobar Islands  1904   9.4   14.7    0.0  202.4  304.5
# 4     Andaman & Nicobar Islands  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4183                Lakshadweep  2013  26.2   34.4   37.5    5.3   88.3
# 4184                Lakshadweep  2014  53.2   16.1    4.4   14.9   57.4
# 4185                Lakshadweep  2015   2.2    0.5    3.7   87.1  133.1
# 4186                Lakshadweep  2016  59.6   12.1    3.2    2.6   77.4
# 4187                Lakshadweep  2017  21.3    0.9  100.2    1.8  145.7
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM  \
# ...

# %%
Kerala = file[file.SUBDIVISION == 'Kerala']

# %%
Kerala
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 3955      Kerala  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 3956      Kerala  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 3957      Kerala  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3958      Kerala  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 3959      Kerala  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
# ...          ...   ...   ...   ...   ...    ...    ...     ...     ...    ...
# 4067      Kerala  2013   3.9  40.1  49.9   49.3  119.3  1042.7   830.2  369.7
# 4068      Kerala  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8  733.9
# 4069      Kerala  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0  252.2
# 4070      Kerala  2016   3.0  16.4  22.4   33.3  258.4   595.7   441.5  231.0
# 4071      Kerala  2017  12.7   0.3  87.8   52.8  213.3   579.8   378.5  462.6
#
# ...

# %%
plt.plot(Kerala.YEAR, Kerala.ANNUAL/10)
plt.plot(Kerala.YEAR, Kerala.JJAS/10)
plt.title("Annual Rainfall for Kerala in cms")
plt.xlabel("YEARS")
plt.ylabel("Rainfall in cm")
plt.legend(["Annual", "JJAS"])
#plt.show()
plt.savefig('kerala.png')

# %%
TamilNadu = file[file.SUBDIVISION == 'Tamil Nadu']

# %%
TamilNadu
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY   JUN   JUL    AUG  \
# 3487  Tamil Nadu  1901  24.5  39.1  21.7   36.0   74.0  41.8  49.3   67.9
# 3488  Tamil Nadu  1902  67.2   9.8  25.1   21.9   84.7  39.3  55.1  113.8
# 3489  Tamil Nadu  1903  19.3   7.8   1.7   18.2  128.5  58.5  72.6  115.0
# 3490  Tamil Nadu  1904  35.2   0.1   0.7   19.5  121.9  34.9  89.0   40.4
# 3491  Tamil Nadu  1905   6.5   7.5  17.2   64.8   83.7  49.8  39.0  101.8
# ...          ...   ...   ...   ...   ...    ...    ...   ...   ...    ...
# 3599  Tamil Nadu  2013   3.9  30.9  30.0   20.3   42.0  54.6  42.7  110.7
# 3600  Tamil Nadu  2014   7.4   6.1   8.1    8.3  139.1  47.8  50.6  117.7
# 3601  Tamil Nadu  2015   8.3   2.3  21.7  108.8  112.4  62.4  43.5   81.6
# 3602  Tamil Nadu  2016   2.5   0.8   3.1    6.3  102.5  63.0  86.8   55.1
# 3603  Tamil Nadu  2017  37.3   1.1  35.4   17.3   73.5  47.9  42.0  159.4
#
#         SEP    OCT    NOV    DEC  ANNUAL    JF    MAM   JJAS    OND
# ...

# %%
plt.plot(TamilNadu.YEAR, TamilNadu.ANNUAL/10)
plt.title("Annual Rainfall for TamilNadu in cms")
plt.xlabel("YEARS")
plt.ylabel("Rainfall in cm")
#plt.show()
plt.savefig('TamilNadu.png')

# %%
#Compare annual rainfall for year 1901-2017 for TamilNadu and Kerala

Kerala = file[file.SUBDIVISION == 'Kerala']
TamilNadu = file[file.SUBDIVISION == 'Tamil Nadu']

plt.plot(Kerala.YEAR, Kerala.ANNUAL/10)
plt.plot(TamilNadu.YEAR, TamilNadu.ANNUAL/10)
plt.title("Annual Rainfall for Kerala and TamilNadu in cms")
plt.xlabel("YEARS")
plt.ylabel("Rainfall in cm")
plt.legend(["Kerala","TamilNadu"])
#plt.show()
plt.savefig('comparision.pdf')
